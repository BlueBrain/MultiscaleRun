# %%
! module list
# Out:
# Currently Loaded Modulefiles:
#   1) archive/2020-11       3) py-bluepysnap/0.6.1
#   2) python/3.7.4          4) py-bluepy/0.14.15

# %% [markdown]
# Currently Loaded Modulefiles:
#   1) archive/2020-11       3) py-bluepysnap/0.6.1
#   2) python/3.7.4          4) py-bluepy/0.14.15

# %%
from bluepy.v2 import Circuit
from bluepy.v2 import Cell
from bluepy.v2.enums import Synapse

# %%
import numpy as np
import pandas as pd
import itertools

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 100)

# %%
c = Circuit('/gpfs/bbp.cscs.ch/project/proj62/Circuits/O1/20190912_spines/CircuitConfig')

# %%
c.cells.available_properties
# Out:
# {'etype',
#  'exc_mini_frequency',
#  'hypercolumn',
#  'inh_mini_frequency',
#  'layer',
#  'me_combo',
#  'morph_class',
#  'morphology',
#  'mtype',
#  'orientation',
#  'region',
#  'synapse_class',
#  'x',
#  'y',
#  'z'}

# %%
c.cells.count()
# Out:
# 163512

# %%
c.cells.etypes
# Out:
# {'bAC',
#  'bIR',
#  'bNAC',
#  'bSTUT',
#  'cACint',
#  'cADpyr',
#  'cIR',
#  'cNAC',
#  'cSTUT',
#  'dNAC',
#  'dSTUT'}

# %%
c.cells.mtypes
# Out:
# {'L1_DAC',
#  'L1_HAC',
#  'L1_LAC',
#  'L1_NGC-DA',
#  'L1_NGC-SA',
#  'L1_SAC',
#  'L23_BP',
#  'L23_BTC',
#  'L23_CHC',
#  'L23_DBC',
#  'L23_LBC',
#  'L23_MC',
#  'L23_NBC',
#  'L23_NGC',
#  'L23_SBC',
#  'L2_IPC',
#  'L2_TPC:A',
#  'L2_TPC:B',
#  'L3_TPC:A',
#  'L3_TPC:B',
#  'L4_BP',
#  'L4_BTC',
#  'L4_CHC',
#  'L4_DBC',
#  'L4_LBC',
#  'L4_MC',
#  'L4_NBC',
#  'L4_NGC',
#  'L4_SBC',
#  'L4_SSC',
#  'L4_TPC',
#  'L4_UPC',
#  'L5_BP',
#  'L5_BTC',
#  'L5_CHC',
#  'L5_DBC',
#  'L5_LBC',
#  'L5_MC',
#  'L5_NBC',
#  'L5_NGC',
#  'L5_SBC',
#  'L5_TPC:A',
#  'L5_TPC:B',
#  'L5_TPC:C',
#  'L5_UPC',
#  'L6_BP',
#  'L6_BPC',
#  'L6_BTC',
#  'L6_CHC',
#  'L6_DBC',
#  'L6_HPC',
#  'L6_IPC',
#  'L6_LBC',
#  'L6_MC',
#  'L6_NBC',
#  'L6_NGC',
#  'L6_SBC',
#  'L6_TPC:A',
#  'L6_TPC:C',
#  'L6_UPC'}

# %%
# In dualrun BC:
#Target Cell select {
#  a79877
#  a66365
#}

# %%
c.cells.get(79877)
# Out:
# x                                                               384.627
# y                                                               662.043
# z                                                               910.871
# orientation           [[0.7691836700810597, -0.0, -0.639027762840263...
# etype                                                            cADpyr
# exc_mini_frequency                                                 0.04
# hypercolumn                                                           6
# inh_mini_frequency                                                0.012
# layer                                                                 6
# me_combo              cADpyr_L6BPC_L6_TPC:A_6_dend-tkb061025b3_ch0_c...
# morph_class                                                         PYR
# morphology            dend-tkb061025b3_ch0_cc2_h_zk_60x_1_axon-Fluo4...
#  'mc3_Column']

# %%
layer_oldL5mc2MCTPCA
# Out:
# [5]

# %%
mtype_oldL5mc2MCTPCA
# Out:
# ['L5_NGC', 'L5_MC', 'L5_TPC:B', 'L5_TPC:A']

# %%
mc2_all_ids = c.cells.ids({Cell.REGION: 'mc2_Column'})

# %%
len(mc2_all_ids)
# Out:
# 23021

# %%
mc2_all = c.cells.get({Cell.REGION: 'mc2_Column'}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])

# %%
len(mc2_all)
# Out:
# 23021

# %%
mc2_L1 = c.cells.get({Cell.REGION: 'mc2_Column', Cell.LAYER: 1}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])
mc2_L2 = c.cells.get({Cell.REGION: 'mc2_Column', Cell.LAYER: 2}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])
mc2_L3 = c.cells.get({Cell.REGION: 'mc2_Column', Cell.LAYER: 3}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])
mc2_L4 = c.cells.get({Cell.REGION: 'mc2_Column', Cell.LAYER: 4}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])
mc2_L5 = c.cells.get({Cell.REGION: 'mc2_Column', Cell.LAYER: 5}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])
mc2_L6 = c.cells.get({Cell.REGION: 'mc2_Column', Cell.LAYER: 6}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])

# %%
# just check
set(itertools.chain.from_iterable(mc2_L1[['synapse_class']].values.tolist()))
# Out:
# {'INH'}

# %%
mc2_L1_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.LAYER: 1})
mc2_L2_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.LAYER: 2})
mc2_L3_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.LAYER: 3})
mc2_L4_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.LAYER: 4})
mc2_L5_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.LAYER: 5})
mc2_L6_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.LAYER: 6})

# %%
mc2_L5.head(2)
# Out:
#         hypercolumn      region   mtype etype synapse_class  layer
# 131333          3.0  mc2_Column  L5_CHC  dNAC           INH      5
# 131337          3.0  mc2_Column  L5_CHC  cNAC           INH      5

# %%
mc2_exc = c.cells.get({Cell.REGION: 'mc2_Column', Cell.SYNAPSE_CLASS: "EXC"}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])
mc2_inh = c.cells.get({Cell.REGION: 'mc2_Column', Cell.SYNAPSE_CLASS: "INH"}, properties=[Cell.HYPERCOLUMN, Cell.REGION, Cell.MTYPE, Cell.ETYPE, Cell.SYNAPSE_CLASS, Cell.LAYER])

# %%
mc2_exc.head(2)
# Out:
#       hypercolumn      region     mtype   etype synapse_class  layer
# 2548          3.0  mc2_Column  L3_TPC:A  cADpyr           EXC      3
# 2550          3.0  mc2_Column  L3_TPC:A  cADpyr           EXC      3

# %%
set(itertools.chain.from_iterable(mc2_exc[['layer']].values.tolist()))
# Out:
# {2, 3, 4, 5, 6}

# %%
mc2_exc_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.SYNAPSE_CLASS: "EXC"})
mc2_inh_ids = c.cells.ids({Cell.REGION: 'mc2_Column', Cell.SYNAPSE_CLASS: "INH"})

# %%
c.cells.get(2548)
# Out:
# x                                                                133.25
# y                                                                1636.2
# z                                                               587.183
# orientation           [[0.9991169852880186, 0.0, 0.04201487485380837...
# etype                                                            cADpyr
# exc_mini_frequency                                                0.122
# hypercolumn                                                           3
# inh_mini_frequency                                                0.012
# layer                                                                 3
# me_combo              cADpyr_L3TPC_L3_TPC:A_3_dend-C170897A-P2_axon-...
# morph_class                                                         PYR
# morphology            dend-C170897A-P2_axon-rp120510_P-2_idA_-_Scale...
# mtype                                                          L3_TPC:A
# ...

# %%
# save data

outpath = "/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/gids_sets/O1_20190912_spines/"

mc2_all_f = outpath + 'mc2_gids.txt'
mc2_exc_f = outpath + 'mc2_exc_gids.txt'
mc2_inh_f = outpath + 'mc2_inh_gids.txt'

mc2_L1_f = outpath + 'mc2_L1_gids.txt'
mc2_L2_f = outpath + 'mc2_L2_gids.txt'
mc2_L3_f = outpath + 'mc2_L3_gids.txt'
mc2_L4_f = outpath + 'mc2_L4_gids.txt'
mc2_L5_f = outpath + 'mc2_L5_gids.txt'
mc2_L6_f = outpath + 'mc2_L6_gids.txt'

# %%
mc2_all_f
# Out:
# '/gpfs/bbp.cscs.ch/project/proj34/metabolismndam/sim/gids_sets/O1_20190912_spines/mc2_gids.txt'

# %%
pd.Series(mc2_all_ids).to_csv(mc2_all_f,sep="\t",index=False,header=None)

pd.Series(mc2_exc_ids).to_csv(mc2_exc_f,sep="\t",index=False,header=None)
pd.Series(mc2_inh_ids).to_csv(mc2_inh_f,sep="\t",index=False,header=None)

pd.Series(mc2_L1_ids).to_csv(mc2_L1_f,sep="\t",index=False,header=None)
pd.Series(mc2_L2_ids).to_csv(mc2_L2_f,sep="\t",index=False,header=None)
pd.Series(mc2_L3_ids).to_csv(mc2_L3_f,sep="\t",index=False,header=None)
pd.Series(mc2_L4_ids).to_csv(mc2_L4_f,sep="\t",index=False,header=None)
pd.Series(mc2_L5_ids).to_csv(mc2_L5_f,sep="\t",index=False,header=None)
pd.Series(mc2_L6_ids).to_csv(mc2_L6_f,sep="\t",index=False,header=None)

# %%
! pwd
# Out:
# /gpfs/bbp.cscs.ch/project/proj34/sh_ngvm/bluepy_prep4circuit

# %% [markdown]
# ### Target for BC

# %%
mc2_L5.shape
# Out:
# (4517, 6)

# %%
mc2_L5.head()
# Out:
#         hypercolumn      region   mtype   etype synapse_class  layer
# 131333          3.0  mc2_Column  L5_CHC    dNAC           INH      5
# 131337          3.0  mc2_Column  L5_CHC    cNAC           INH      5
# 131342          3.0  mc2_Column  L5_CHC    cNAC           INH      5
# 131343          3.0  mc2_Column  L5_CHC    cNAC           INH      5
# 131344          3.0  mc2_Column  L5_CHC  cACint           INH      5

# %%
mc2_L5['mtype'].unique()
# Out:
# [L5_CHC, L5_TPC:C, L5_LBC, L5_SBC, L5_UPC, ..., L5_TPC:B, L5_TPC:A, L5_NGC, L5_MC, L5_BP]
# Length: 13
# Categories (13, object): [L5_CHC, L5_TPC:C, L5_LBC, L5_SBC, ..., L5_TPC:A, L5_NGC, L5_MC, L5_BP]

# %%
mc2_L5.loc[mc2_L5['mtype']=='L5_TPC:A',:].head()
# Out:
#         hypercolumn      region     mtype   etype synapse_class  layer
# 150773          3.0  mc2_Column  L5_TPC:A  cADpyr           EXC      5
# 150967          3.0  mc2_Column  L5_TPC:A  cADpyr           EXC      5
# 150968          3.0  mc2_Column  L5_TPC:A  cADpyr           EXC      5
# 150969          3.0  mc2_Column  L5_TPC:A  cADpyr           EXC      5
# 150970          3.0  mc2_Column  L5_TPC:A  cADpyr           EXC      5

# %%
mc2_L5.loc[mc2_L5['mtype']=='L5_TPC:A',:].index[0]
# Out:
# 150773

# %%
c.connectome.available_properties
# Out:
# {<Synapse.AXONAL_DELAY: 'axonal_delay'>,
#  <Synapse.DTC: 'DTC'>,
#  <Synapse.D_SYN: 'd_syn'>,
#  <Synapse.F_SYN: 'f_syn'>,
#  <Synapse.G_SYNX: 'g_synx'>,
#  <Synapse.NRRP: 'NRRP'>,
#  <Synapse.POST_BRANCH_TYPE: 'post_branch_type'>,
#  <Synapse.POST_GID: 'post_gid'>,
#  <Synapse.POST_SECTION_ID: 'post_section_id'>,
#  <Synapse.POST_X_CENTER: 'post_x_center'>,
#  <Synapse.POST_Y_CENTER: 'post_y_center'>,
#  <Synapse.POST_Z_CENTER: 'post_z_center'>,
#  <Synapse.PRE_GID: 'pre_gid'>,
#  <Synapse.PRE_SECTION_ID: 'pre_section_id'>,
#  <Synapse.PRE_X_CONTOUR: 'pre_x_contour'>,
#  <Synapse.PRE_Y_CONTOUR: 'pre_y_contour'>,
#  <Synapse.PRE_Z_CONTOUR: 'pre_z_contour'>,
#  <Synapse.TYPE: 'type'>,
#  <Synapse.U_SYN: 'u_syn'>,
#  '_POST_DISTANCE',
#  '_POST_SEGMENT_ID',
#  '_PRE_DISTANCE',
#  '_PRE_SEGMENT_ID',
#  'afferent_section_pos',
#  'efferent_section_pos',
#  'efferent_section_type',
#  'spine_length'}

# %%
selected_cell = mc2_L5.loc[mc2_L5['mtype']=='L5_TPC:A',:].index[0]
selected_cell
# Out:
# 150773

# %%
connections_l5tpca1 = list(c.connectome.afferent_gids(gid=selected_cell))

# %%
c.cells.get(connections_l5tpca1,properties=[Cell.MTYPE, Cell.SYNAPSE_CLASS])
# Out:
#            mtype synapse_class
# 3533    L3_TPC:A           EXC
# 3945    L3_TPC:A           EXC
# 4544    L3_TPC:A           EXC
# 5149    L3_TPC:A           EXC
# 5535    L3_TPC:A           EXC
# 5536    L3_TPC:A           EXC
# 5845    L3_TPC:A           EXC
# 6038    L3_TPC:A           EXC
# 6630    L3_TPC:A           EXC
# 6899    L3_TPC:A           EXC
# 9877    L3_TPC:A           EXC
# 10209   L3_TPC:A           EXC
# 21095     L23_MC           INH
# 22579   L3_TPC:B           EXC
# 23491   L3_TPC:B           EXC
# 25258   L3_TPC:B           EXC
# 48045     L6_HPC           EXC
# 48075     L6_HPC           EXC
# 49944     L6_HPC           EXC
# 50969     L6_HPC           EXC
# 69155     L6_IPC           EXC
# 69867     L6_IPC           EXC
# 76904   L6_TPC:A           EXC
# 90843     L4_UPC           EXC
# 91020     L4_UPC           EXC
# 91182     L4_UPC           EXC
# 91209     L4_UPC           EXC
# 91216     L4_UPC           EXC
# 92632     L4_UPC           EXC
# ...

# %%
# for user.target for mesh box definition:

with open('mc2_Column_target.txt','w') as f:
    f.write("Target Cell mc2_Column\n{\n  ")
    
    for cell in mc2_all_ids:
        
        f.write(f"a{cell} ")
    
    f.write("\n}\n")
    
    f.write("Target Compartment AllComps_mc2_Column\n{\n  ")
    f.write("  mc2_Column\n")
    f.write("\n}\n\n")

# %%
# for user.target testing code:

L5tpcaChc_t = '''Target Cell L5tpcaChc
{
  a150773
  a131313
}

Target Compartment AllComps_L5tpcaChc
{
  L5tpcaChc
}\n\n'''


with open('testL5tpcaChc_target.txt','w') as f:
    f.write(L5tpcaChc_t)
    f.write("\n")

# %%
# for BC:

# replace L5mc2MCTPCA with L5tpcaChc or mc2_Column depending on run purpose
# and replace AllComps_l5s1 with AllComps_L5tpcaChc or AllComps_mc2_Column depending on run purpose

# %%
! pwd
# Out:
# /gpfs/bbp.cscs.ch/project/proj34/sh_ngvm/bluepy_prep4circuit
